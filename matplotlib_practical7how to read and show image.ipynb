# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread("imadehradun.jpg")

# %%
img
# Out:
# array([[[ 22,  33,  17],
#         [ 24,  35,  19],
#         [ 27,  38,  22],
#         ...,
#         [ 61,  77,  76],
#         [ 61,  77,  76],
#         [ 61,  77,  76]],
#
#        [[ 26,  37,  21],
#         [ 28,  39,  23],
#         [ 30,  41,  25],
#         ...,
#         [ 59,  75,  74],
#         [ 58,  74,  73],
#         [ 58,  74,  73]],
#
#        [[ 33,  44,  28],
#         [ 34,  45,  29],
#         [ 36,  47,  31],
#         ...,
#         [ 45,  61,  60],
#         [ 44,  60,  59],
#         [ 43,  59,  58]],
#
#        ...,
#
#        [[105,  96,  87],
#         [105,  96,  87],
#         [106,  97,  88],
#         ...,
#         [115, 106,  97],
#         [113, 104,  95],
#         [113, 104,  95]],
#
#        [[105,  96,  87],
#         [106,  97,  88],
#         [107,  98,  89],
#         ...,
#         [115, 106,  97],
#         [114, 105,  96],
#         [113, 104,  95]],
#
#        [[105,  96,  87],
#         [105,  96,  87],
#         [106,  97,  88],
# ...

# %%
plt.figure(figsize = (11,6))
plt.axis("off")
plt.imshow(img)
plt.colorbar()
plt.show()
